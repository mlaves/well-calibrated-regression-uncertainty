# %%
# %matplotlib notebook
import torch
import matplotlib
from matplotlib import pyplot as plt
from data_generator_oct import OCTDataset
import numpy as np
from scipy.ndimage import zoom

import seaborn as sns
sns.set()
sns.set_style("whitegrid", {'axes.grid' : False})
sns.set_style('ticks')

matplotlib.rcParams['text.usetex'] = True
matplotlib.rcParams['font.size'] = 8
matplotlib.rcParams['text.latex.preamble'] = [
    r'\usepackage{bm}']

# %%
data_dir = '/media/data/oct_data_needle/data'
data_set = OCTDataset(data_dir=data_dir, augment=False)
assert len(data_set) > 0

# %%
img, _ = data_set[0]
img = img.numpy()
print(img.shape)
# Out:
# (3, 256, 256)

# %%
fig, ax = plt.subplots(1, 3, figsize=(6.0, 2.5))

ax[0].imshow(img[0])
ax[0].set_title(r'$\arg\max_{x}$')

ax[1].imshow(img[1])
ax[1].set_title(r'$\arg\max_{y}$')
ax[2].imshow(img[2])
ax[2].set_title(r'$\arg\max_{z}$')

fig.tight_layout()
fig.show()
fig.savefig("oct_datset.pdf", bbox_inches='tight')
# Out:
# <img src="data:image/png;base64,..." width="600">
